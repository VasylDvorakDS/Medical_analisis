# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
def read_data(path='clinical.tsv'):
    df = pd.read_csv(path, sep='\t')
    columns=df.columns
    rows=len(df)
    for column in columns:
        if (df[column]=="'--").sum() == rows:
          df.drop(columns=[column], inplace=True)
          continue
        df[column]=df[column].replace("'--", df[column].max())

    display(df.head())
    display(df.apply(lambda col: col.value_counts().head(), axis=0))
    display(df.info())
    display(df.describe())
    print('duplicated=', df.duplicated().sum())
    return df

df_clinical = read_data()
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 1  0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 2  0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 3  0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 4  0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
#
#   age_at_index days_to_birth days_to_death               ethnicity  gender  \
# 0           61        -22454           248  not hispanic or latino  female
# 1           61        -22454           248  not hispanic or latino  female
# 2           73        -27025            58  not hispanic or latino    male
# 3           73        -27025            58  not hispanic or latino    male
# 4           27        -10075           391      hispanic or latino  female
#
#     race vital_status year_of_birth year_of_death age_at_diagnosis  \
# 0  asian         Dead          1952          2012            22454
# 1  asian         Dead          1952          2012            22454
# 2  asian         Dead          1940          2012            27025
# 3  asian         Dead          1940          2012            27025
# 4  white         Dead          1984          2012            10075
#
#   ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# 0                   No                  Stage I
# 1                   No                  Stage I
# 2                   No                 Stage IV
# 3                   No                 Stage IV
# 4                   No                 Stage II
#
#   ann_arbor_extranodal_involvement classification_of_tumor days_to_diagnosis  \
# 0                               No            not reported                 0
# 1                               No            not reported                 0
# 2                               No            not reported                 0
# 3                               No            not reported                 0
# 4                               No            not reported                 0
#
#   days_to_last_follow_up icd_10_code last_known_disease_status morphology  \
# 0                     22       C48.1              not reported     9680/3
# 1                     22       C48.1              not reported     9680/3
# 2                      6       C83.3              not reported     9680/3
# 3                      6       C83.3              not reported     9680/3
# 4                    982       C83.3              not reported     9680/3
#
#                                 primary_diagnosis prior_malignancy  \
# 0  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 1  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 2  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 3  Malignant lymphoma, large B-cell, diffuse, NOS               no
# 4  Malignant lymphoma, large B-cell, diffuse, NOS               no
#
#   prior_treatment progression_or_recurrence  \
# 0              No              not reported
# 1              No              not reported
# 2              No              not reported
# 3              No              not reported
# 4              No              not reported
#
#           site_of_resection_or_biopsy synchronous_malignancy  \
# 0         Intra-abdominal lymph nodes                     No
# 1         Intra-abdominal lymph nodes                     No
# 2  Lymph nodes of head, face and neck                     No
# 3  Lymph nodes of head, face and neck                     No
# 4  Lymph nodes of head, face and neck                     No
#
#             tissue_or_organ_of_origin   tumor_grade year_of_diagnosis  \
# 0         Intra-abdominal lymph nodes  not reported              2013
# 1         Intra-abdominal lymph nodes  not reported              2013
# 2  Lymph nodes of head, face and neck  not reported              2013
# 3  Lymph nodes of head, face and neck  not reported              2013
# 4  Lymph nodes of head, face and neck  not reported              2011
#
#   treatment_or_therapy               treatment_type
# 0                  yes  Pharmaceutical Therapy, NOS
# 1                   no       Radiation Therapy, NOS
# 2                   no       Radiation Therapy, NOS
# 3                  yes  Pharmaceutical Therapy, NOS
# 4                  yes  Pharmaceutical Therapy, NOS
#                         case_id  case_submitter_id  project_id  age_at_index  \
# -10075                      NaN                NaN         NaN           NaN
# -21959                      NaN                NaN         NaN           NaN
# -22454                      NaN                NaN         NaN           NaN
# -27025                      NaN                NaN         NaN           NaN
# -8493                       NaN                NaN         NaN           NaN
# ...                         ...                ...         ...           ...
# no                          NaN                NaN         NaN           NaN
# not hispanic or latino      NaN                NaN         NaN           NaN
# not reported                NaN                NaN         NaN           NaN
# white                       NaN                NaN         NaN           NaN
# yes                         NaN                NaN         NaN           NaN
#
#                         days_to_birth  days_to_death  ethnicity  gender  race  \
# -10075                            2.0            NaN        NaN     NaN   NaN
# -21959                            2.0            NaN        NaN     NaN   NaN
# -22454                            2.0            NaN        NaN     NaN   NaN
# -27025                            2.0            NaN        NaN     NaN   NaN
# -8493                            12.0            NaN        NaN     NaN   NaN
# ...                               ...            ...        ...     ...   ...
# no                                NaN            NaN        NaN     NaN   NaN
# not hispanic or latino            NaN            NaN       82.0     NaN   NaN
# not reported                      NaN            NaN        NaN     NaN   NaN
# white                             NaN            NaN        NaN     NaN  68.0
# yes                               NaN            NaN        NaN     NaN   NaN
#
#                         vital_status  year_of_birth  year_of_death  \
# -10075                           NaN            NaN            NaN
# -21959                           NaN            NaN            NaN
# -22454                           NaN            NaN            NaN
# -27025                           NaN            NaN            NaN
# -8493                            NaN            NaN            NaN
# ...                              ...            ...            ...
# no                               NaN            NaN            NaN
# not hispanic or latino           NaN            NaN            NaN
# not reported                     NaN            NaN            NaN
# white                            NaN            NaN            NaN
# yes                              NaN            NaN            NaN
#
#                         age_at_diagnosis  ann_arbor_b_symptoms  \
# -10075                               NaN                   NaN
# -21959                               NaN                   NaN
# -22454                               NaN                   NaN
# -27025                               NaN                   NaN
# -8493                                NaN                   NaN
# ...                                  ...                   ...
# no                                   NaN                   NaN
# not hispanic or latino               NaN                   NaN
# not reported                         NaN                   NaN
# white                                NaN                   NaN
# yes                                  NaN                   NaN
#
#                         ann_arbor_clinical_stage  \
# -10075                                       NaN
# -21959                                       NaN
# -22454                                       NaN
# -27025                                       NaN
# -8493                                        NaN
# ...                                          ...
# no                                           NaN
# not hispanic or latino                       NaN
# not reported                                 NaN
# white                                        NaN
# yes                                          NaN
#
#                         ann_arbor_extranodal_involvement  \
# -10075                                               NaN
# -21959                                               NaN
# -22454                                               NaN
# -27025                                               NaN
# -8493                                                NaN
# ...                                                  ...
# no                                                   NaN
# not hispanic or latino                               NaN
# not reported                                         NaN
# white                                                NaN
# yes                                                  NaN
#
#                         classification_of_tumor  days_to_diagnosis  \
# -10075                                      NaN                NaN
# -21959                                      NaN                NaN
# -22454                                      NaN                NaN
# -27025                                      NaN                NaN
# -8493                                       NaN                NaN
# ...                                         ...                ...
# no                                          NaN                NaN
# not hispanic or latino                      NaN                NaN
# not reported                              106.0                NaN
# white                                       NaN                NaN
# yes                                         NaN                NaN
#
#                         days_to_last_follow_up  icd_10_code  \
# -10075                                     NaN          NaN
# -21959                                     NaN          NaN
# -22454                                     NaN          NaN
# -27025                                     NaN          NaN
# -8493                                      NaN          NaN
# ...                                        ...          ...
# no                                         NaN          NaN
# not hispanic or latino                     NaN          NaN
# not reported                               NaN          NaN
# white                                      NaN          NaN
# yes                                        NaN          NaN
#
#                         last_known_disease_status  morphology  \
# -10075                                        NaN         NaN
# -21959                                        NaN         NaN
# -22454                                        NaN         NaN
# -27025                                        NaN         NaN
# -8493                                         NaN         NaN
# ...                                           ...         ...
# no                                            NaN         NaN
# not hispanic or latino                        NaN         NaN
# not reported                                106.0         NaN
# white                                         NaN         NaN
# yes                                           NaN         NaN
#
#                         primary_diagnosis  prior_malignancy  prior_treatment  \
# -10075                                NaN               NaN              NaN
# -21959                                NaN               NaN              NaN
# -22454                                NaN               NaN              NaN
# -27025                                NaN               NaN              NaN
# -8493                                 NaN               NaN              NaN
# ...                                   ...               ...              ...
# no                                    NaN             106.0              NaN
# not hispanic or latino                NaN               NaN              NaN
# not reported                          NaN               NaN              NaN
# white                                 NaN               NaN              NaN
# yes                                   NaN               NaN              NaN
#
#                         progression_or_recurrence  \
# -10075                                        NaN
# -21959                                        NaN
# -22454                                        NaN
# -27025                                        NaN
# -8493                                         NaN
# ...                                           ...
# no                                            NaN
# not hispanic or latino                        NaN
# not reported                                106.0
# white                                         NaN
# yes                                           NaN
#
#                         site_of_resection_or_biopsy  synchronous_malignancy  \
# -10075                                          NaN                     NaN
# -21959                                          NaN                     NaN
# -22454                                          NaN                     NaN
# -27025                                          NaN                     NaN
# -8493                                           NaN                     NaN
# ...                                             ...                     ...
# no                                              NaN                     NaN
# not hispanic or latino                          NaN                     NaN
# not reported                                    NaN                     NaN
# white                                           NaN                     NaN
# yes                                             NaN                     NaN
#
#                         tissue_or_organ_of_origin  tumor_grade  \
# -10075                                        NaN          NaN
# -21959                                        NaN          NaN
# -22454                                        NaN          NaN
# -27025                                        NaN          NaN
# -8493                                         NaN          NaN
# ...                                           ...          ...
# no                                            NaN          NaN
# not hispanic or latino                        NaN          NaN
# not reported                                  NaN        106.0
# white                                         NaN          NaN
# yes                                           NaN          NaN
#
#                         year_of_diagnosis  treatment_or_therapy  \
# -10075                                NaN                   NaN
# -21959                                NaN                   NaN
# -22454                                NaN                   NaN
# -27025                                NaN                   NaN
# -8493                                 NaN                   NaN
# ...                                   ...                   ...
# no                                    NaN                  43.0
# not hispanic or latino                NaN                   NaN
# not reported                          NaN                   2.0
# white                                 NaN                   NaN
# yes                                   NaN                  61.0
#
#                         treatment_type
# -10075                             NaN
# -21959                             NaN
# -22454                             NaN
# -27025                             NaN
# -8493                              NaN
# ...                                ...
# no                                 NaN
# not hispanic or latino             NaN
# not reported                       NaN
# white                              NaN
# yes                                NaN
#
# [82 rows x 33 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case_id                           106 non-null    object
#  1   case_submitter_id                 106 non-null    object
#  2   project_id                        106 non-null    object
#  3   age_at_index                      106 non-null    object
#  4   days_to_birth                     106 non-null    object
#  5   days_to_death                     106 non-null    object
#  6   ethnicity                         106 non-null    object
#  7   gender                            106 non-null    object
#  8   race                              106 non-null    object
#  9   vital_status                      106 non-null    object
#  10  year_of_birth                     106 non-null    object
#  11  year_of_death                     106 non-null    object
#  12  age_at_diagnosis                  106 non-null    object
#  13  ann_arbor_b_symptoms              106 non-null    object
#  14  ann_arbor_clinical_stage          106 non-null    object
#  15  ann_arbor_extranodal_involvement  106 non-null    object
#  16  classification_of_tumor           106 non-null    object
#  17  days_to_diagnosis                 106 non-null    object
#  18  days_to_last_follow_up            106 non-null    object
#  19  icd_10_code                       106 non-null    object
#  20  last_known_disease_status         106 non-null    object
#  21  morphology                        106 non-null    object
#  22  primary_diagnosis                 106 non-null    object
#  23  prior_malignancy                  106 non-null    object
#  24  prior_treatment                   106 non-null    object
#  25  progression_or_recurrence         106 non-null    object
#  26  site_of_resection_or_biopsy       106 non-null    object
#  27  synchronous_malignancy            106 non-null    object
#  28  tissue_or_organ_of_origin         106 non-null    object
#  29  tumor_grade                       106 non-null    object
#  30  year_of_diagnosis                 106 non-null    object
#  31  treatment_or_therapy              106 non-null    object
#  32  treatment_type                    106 non-null    object
# dtypes: object(33)
# memory usage: 27.5+ KB
# None
#                                      case_id case_submitter_id project_id  \
# count                                    106               106        106
# unique                                    58                58          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       2                 2        106
#
#        age_at_index days_to_birth days_to_death               ethnicity  \
# count           106           106           106                     106
# unique           34            48             9                       2
# top              82         -8493           708  not hispanic or latino
# freq             12            12            90                      82
#
#        gender   race vital_status year_of_birth year_of_death  \
# count     106    106          106           106           106
# unique      2      3            2            34             4
# top      male  white        Alive          1987          2012
# freq       54     68           78            12           100
#
#        age_at_diagnosis ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# count               106                  106                      106
# unique               48                    2                        4
# top                8493                   No                 Stage IV
# freq                 12                   70                       46
#
#        ann_arbor_extranodal_involvement classification_of_tumor  \
# count                               106                     106
# unique                                2                       1
# top                                 Yes            not reported
# freq                                 56                     106
#
#        days_to_diagnosis days_to_last_follow_up icd_10_code  \
# count                106                    106         106
# unique                 1                     41          10
# top                    0                    982       C83.3
# freq                 106                     22          86
#
#        last_known_disease_status morphology  \
# count                        106        106
# unique                         1          1
# top                 not reported     9680/3
# freq                         106        106
#
#                                      primary_diagnosis prior_malignancy  \
# count                                              106              106
# unique                                               1                1
# top     Malignant lymphoma, large B-cell, diffuse, NOS               no
# freq                                               106              106
#
#        prior_treatment progression_or_recurrence  \
# count              106                       106
# unique               2                         1
# top                 No              not reported
# freq                94                       106
#
#                site_of_resection_or_biopsy synchronous_malignancy  \
# count                                  106                    106
# unique                                  20                      1
# top     Lymph nodes of head, face and neck                     No
# freq                                    32                    106
#
#                  tissue_or_organ_of_origin   tumor_grade year_of_diagnosis  \
# count                                  106           106               106
# unique                                  20             1                14
# top     Lymph nodes of head, face and neck  not reported              2013
# freq                                    32           106                28
#
#        treatment_or_therapy          treatment_type
# count                   106                     106
# unique                    3                       2
# top                     yes  Radiation Therapy, NOS
# freq                     61                      58
# duplicated= 0

# %%
df_exposure = read_data('exposure.tsv')
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# 1  0bf573ac-cd1e-42d8-90cf-b30d7b08679c      TCGA-FA-A6HN  TCGA-DLBC
# 2  0e251c03-bf86-4ed8-b45d-3cbc97160502      TCGA-GS-A9U4  TCGA-DLBC
# 3  0e9fcccc-0630-408d-a121-2c6413824cb7      TCGA-FF-8062  TCGA-DLBC
# 4  1843c82e-7a35-474f-9f79-c0a9af9aa09c      TCGA-FA-A4BB  TCGA-DLBC
#
#   alcohol_history
# 0    Not Reported
# 1    Not Reported
# 2    Not Reported
# 3    Not Reported
# 4    Not Reported
#                                       case_id  case_submitter_id  project_id  \
# 0030a28c-81aa-44b0-8be0-b35e1dcbf98c      1.0                NaN         NaN
# 0bf573ac-cd1e-42d8-90cf-b30d7b08679c      1.0                NaN         NaN
# 0e251c03-bf86-4ed8-b45d-3cbc97160502      1.0                NaN         NaN
# 0e9fcccc-0630-408d-a121-2c6413824cb7      1.0                NaN         NaN
# 1843c82e-7a35-474f-9f79-c0a9af9aa09c      1.0                NaN         NaN
# Not Reported                              NaN                NaN         NaN
# TCGA-DLBC                                 NaN                NaN        48.0
# TCGA-FA-A4BB                              NaN                1.0         NaN
# TCGA-FA-A6HN                              NaN                1.0         NaN
# TCGA-FA-A7Q1                              NaN                1.0         NaN
# TCGA-FF-8062                              NaN                1.0         NaN
# TCGA-GS-A9U4                              NaN                1.0         NaN
#
#                                       alcohol_history
# 0030a28c-81aa-44b0-8be0-b35e1dcbf98c              NaN
# 0bf573ac-cd1e-42d8-90cf-b30d7b08679c              NaN
# 0e251c03-bf86-4ed8-b45d-3cbc97160502              NaN
# 0e9fcccc-0630-408d-a121-2c6413824cb7              NaN
# 1843c82e-7a35-474f-9f79-c0a9af9aa09c              NaN
# Not Reported                                     48.0
# TCGA-DLBC                                         NaN
# TCGA-FA-A4BB                                      NaN
# TCGA-FA-A6HN                                      NaN
# TCGA-FA-A7Q1                                      NaN
# TCGA-FF-8062                                      NaN
# TCGA-GS-A9U4                                      NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   case_id            48 non-null     object
#  1   case_submitter_id  48 non-null     object
#  2   project_id         48 non-null     object
#  3   alcohol_history    48 non-null     object
# dtypes: object(4)
# memory usage: 1.6+ KB
# None
#                                      case_id case_submitter_id project_id  \
# count                                     48                48         48
# unique                                    48                48          1
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1  TCGA-DLBC
# freq                                       1                 1         48
#
#        alcohol_history
# count               48
# unique               1
# top       Not Reported
# freq                48
# duplicated= 0

# %%
pd.read_csv('family_history.tsv', sep='\t').head()
# Out:
# Empty DataFrame
# Columns: [case_id, case_submitter_id, project_id, relationship_age_at_diagnosis, relationship_gender, relationship_primary_diagnosis, relationship_type, relative_with_cancer_history, relatives_with_cancer_history_count]
# Index: []

# %%
pd.read_csv('follow_up.tsv', sep='\t').head()
# Out:
# Empty DataFrame
# Columns: [case_id, case_submitter_id, project_id, adverse_event, adverse_event_grade, aids_risk_factors, barretts_esophagus_goblet_cells_present, bmi, body_surface_area, cause_of_response, cd4_count, cdc_hiv_risk_factors, comorbidity, comorbidity_method_of_diagnosis, days_to_adverse_event, days_to_comorbidity, days_to_follow_up, days_to_imaging, days_to_progression, days_to_progression_free, days_to_recurrence, diabetes_treatment_type, disease_response, dlco_ref_predictive_percent, ecog_performance_status, evidence_of_recurrence_type, eye_color, fev1_fvc_post_bronch_percent, fev1_fvc_pre_bronch_percent, fev1_ref_post_bronch_percent, fev1_ref_pre_bronch_percent, follow_up_id, follow_up_submitter_id, haart_treatment_indicator, height, hepatitis_sustained_virological_response, history_of_tumor, history_of_tumor_type, hiv_viral_load, hormonal_contraceptive_type, hormonal_contraceptive_use, hormone_replacement_therapy_type, hpv_positive_type, hysterectomy_margins_involved, hysterectomy_type, imaging_result, imaging_type, immunosuppressive_treatment_type, karnofsky_performance_status, menopause_status, nadir_cd4_count, pancreatitis_onset_year, pregnancy_outcome, procedures_performed, progression_or_recurrence, progression_or_recurrence_anatomic_site, progression_or_recurrence_type, recist_targeted_regions_number, recist_targeted_regions_sum, reflux_treatment_type, risk_factor, risk_factor_treatment, scan_tracer_used, undescended_testis_corrected, undescended_testis_corrected_age, undescended_testis_corrected_laterality, undescended_testis_corrected_method, undescended_testis_history, undescended_testis_history_laterality, viral_hepatitis_serologies, weight, aa_change, antigen, biospecimen_type, biospecimen_volume, blood_test_normal_range_lower, blood_test_normal_range_upper, cell_count, chromosome, clonality, copy_number, cytoband, days_to_test, exon, gene_symbol, histone_family, histone_variant, intron, laboratory_test, loci_abnormal_count, loci_count, locus, mismatch_repair_mutation, mitotic_count, mitotic_total_area, molecular_analysis_method, molecular_consequence, molecular_test_id, molecular_test_submitter_id, pathogenicity, ...]
# Index: []

# %%
pd.read_csv('pathology_detail.tsv', sep='\t').head()
# Out:
# Empty DataFrame
# Columns: [case_id, case_submitter_id, project_id, diagnosis_id, diagnosis_submitter_id, additional_pathology_findings, anaplasia_present, anaplasia_present_type, bone_marrow_malignant_cells, breslow_thickness, circumferential_resection_margin, columnar_mucosa_present, consistent_pathology_review, dysplasia_degree, dysplasia_type, greatest_tumor_dimension, gross_tumor_weight, largest_extrapelvic_peritoneal_focus, lymph_node_involved_site, lymph_node_involvement, lymph_nodes_positive, lymph_nodes_tested, lymphatic_invasion_present, margin_status, metaplasia_present, morphologic_architectural_pattern, necrosis_percent, necrosis_present, non_nodal_regional_disease, non_nodal_tumor_deposits, number_proliferating_cells, pathology_detail_id, pathology_detail_submitter_id, percent_tumor_invasion, perineural_invasion_present, peripancreatic_lymph_nodes_positive, peripancreatic_lymph_nodes_tested, prostatic_chips_positive_count, prostatic_chips_total_count, prostatic_involvement_percent, residual_tumor, rhabdoid_percent, rhabdoid_present, sarcomatoid_percent, sarcomatoid_present, size_extraocular_nodule, transglottic_extension, tumor_largest_dimension_diameter, tumor_thickness, vascular_invasion_present, vascular_invasion_type]
# Index: []

# %% [markdown]
# # Далее будем работат только с df_clinical

# %%
df=df_clinical

# %%
columns=df.columns
rows=len(df)
for column in columns:
  count=df[column].nunique()
  if count==1:
     df.drop(columns=[column], inplace=True)

df.describe()
# Out:
#                                      case_id case_submitter_id age_at_index  \
# count                                    106               106          106
# unique                                    58                58           34
# top     0030a28c-81aa-44b0-8be0-b35e1dcbf98c      TCGA-FA-A7Q1           82
# freq                                       2                 2           12
#
#        days_to_birth days_to_death               ethnicity gender   race  \
# count            106           106                     106    106    106
# unique            48             9                       2      2      3
# top            -8493           708  not hispanic or latino   male  white
# freq              12            90                      82     54     68
#
#        vital_status year_of_birth year_of_death age_at_diagnosis  \
# count           106           106           106              106
# unique            2            34             4               48
# top           Alive          1987          2012             8493
# freq             78            12           100               12
#
#        ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# count                   106                      106
# unique                    2                        4
# top                      No                 Stage IV
# freq                     70                       46
#
#        ann_arbor_extranodal_involvement days_to_last_follow_up icd_10_code  \
# count                               106                    106         106
# unique                                2                     41          10
# top                                 Yes                    982       C83.3
# freq                                 56                     22          86
#
#        prior_treatment         site_of_resection_or_biopsy  \
# count              106                                 106
# unique               2                                  20
# top                 No  Lymph nodes of head, face and neck
# freq                94                                  32
#
#                  tissue_or_organ_of_origin year_of_diagnosis  \
# count                                  106               106
# unique                                  20                14
# top     Lymph nodes of head, face and neck              2013
# freq                                    32                28
#
#        treatment_or_therapy          treatment_type
# count                   106                     106
# unique                    3                       2
# top                     yes  Radiation Therapy, NOS
# freq                     61                      58

# %%
df.drop(columns=['case_id', 'case_submitter_id', 'treatment_or_therapy'], inplace=True)
df.head()
# Out:
#   age_at_index days_to_birth days_to_death               ethnicity  gender  \
# 0           61        -22454           248  not hispanic or latino  female
# 1           61        -22454           248  not hispanic or latino  female
# 2           73        -27025            58  not hispanic or latino    male
# 3           73        -27025            58  not hispanic or latino    male
# 4           27        -10075           391      hispanic or latino  female
#
#     race vital_status year_of_birth year_of_death age_at_diagnosis  \
# 0  asian         Dead          1952          2012            22454
# 1  asian         Dead          1952          2012            22454
# 2  asian         Dead          1940          2012            27025
# 3  asian         Dead          1940          2012            27025
# 4  white         Dead          1984          2012            10075
#
#   ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# 0                   No                  Stage I
# 1                   No                  Stage I
# 2                   No                 Stage IV
# 3                   No                 Stage IV
# 4                   No                 Stage II
#
#   ann_arbor_extranodal_involvement days_to_last_follow_up icd_10_code  \
# 0                               No                     22       C48.1
# 1                               No                     22       C48.1
# 2                               No                      6       C83.3
# 3                               No                      6       C83.3
# 4                               No                    982       C83.3
#
#   prior_treatment         site_of_resection_or_biopsy  \
# 0              No         Intra-abdominal lymph nodes
# 1              No         Intra-abdominal lymph nodes
# 2              No  Lymph nodes of head, face and neck
# 3              No  Lymph nodes of head, face and neck
# 4              No  Lymph nodes of head, face and neck
#
#             tissue_or_organ_of_origin year_of_diagnosis  \
# 0         Intra-abdominal lymph nodes              2013
# 1         Intra-abdominal lymph nodes              2013
# 2  Lymph nodes of head, face and neck              2013
# 3  Lymph nodes of head, face and neck              2013
# 4  Lymph nodes of head, face and neck              2011
#
#                 treatment_type
# 0  Pharmaceutical Therapy, NOS
# 1       Radiation Therapy, NOS
# 2       Radiation Therapy, NOS
# 3  Pharmaceutical Therapy, NOS
# 4  Pharmaceutical Therapy, NOS

# %%
int_features=['age_at_index', 'days_to_birth', 'days_to_death', 'year_of_birth', 'year_of_death', 'age_at_diagnosis', 'days_to_last_follow_up', 'year_of_diagnosis']
for column in int_features:
  df[column]=df[column].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age_at_index                      106 non-null    int64
#  1   days_to_birth                     106 non-null    int64
#  2   days_to_death                     106 non-null    int64
#  3   ethnicity                         106 non-null    object
#  4   gender                            106 non-null    object
#  5   race                              106 non-null    object
#  6   vital_status                      106 non-null    object
#  7   year_of_birth                     106 non-null    int64
#  8   year_of_death                     106 non-null    int64
#  9   age_at_diagnosis                  106 non-null    int64
#  10  ann_arbor_b_symptoms              106 non-null    object
#  11  ann_arbor_clinical_stage          106 non-null    object
#  12  ann_arbor_extranodal_involvement  106 non-null    object
#  13  days_to_last_follow_up            106 non-null    int64
#  14  icd_10_code                       106 non-null    object
#  15  prior_treatment                   106 non-null    object
#  16  site_of_resection_or_biopsy       106 non-null    object
#  17  tissue_or_organ_of_origin         106 non-null    object
#  18  year_of_diagnosis                 106 non-null    int64
#  19  treatment_type                    106 non-null    object
# dtypes: int64(8), object(12)
# memory usage: 16.7+ KB

# %%
columns= df.columns
columns
# Out:
# Index(['age_at_index', 'days_to_birth', 'days_to_death', 'ethnicity', 'gender',
#        'race', 'vital_status', 'year_of_birth', 'year_of_death',
#        'age_at_diagnosis', 'ann_arbor_b_symptoms', 'ann_arbor_clinical_stage',
#        'ann_arbor_extranodal_involvement', 'days_to_last_follow_up',
#        'icd_10_code', 'prior_treatment', 'site_of_resection_or_biopsy',
#        'tissue_or_organ_of_origin', 'year_of_diagnosis', 'treatment_type'],
#       dtype='object')

# %%
for column in columns:
  fig, axes = plt.subplots(1, 3, figsize=(12, 5))

  sns.boxplot(y=df[column], ax=axes[0])
  axes[0].set_title('Boxplot для '+column)

  sns.countplot(x=df[column], ax=axes[1])
  axes[1].set_title('Countplot для '+column)
  axes[1].tick_params(axis='x', rotation=45)

  sns.violinplot(x=df[column], ax=axes[2], hue=df['treatment_type'])
  axes[2].set_title('Violinplot для '+column)
  axes[2].tick_params(axis='x', rotation=45)

  plt.suptitle(f'Drowings for {column}')
  plt.tight_layout()
  plt.show()

# %% [markdown]
# # Для того чтобы выяснить какие признаки больше всего влияют на целевую переменную treatment_type необходимо построить матрицу корреляции. Но для этого необходимо сначала сделать LabelEncoding.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age_at_index                      106 non-null    int64
#  1   days_to_birth                     106 non-null    int64
#  2   days_to_death                     106 non-null    int64
#  3   ethnicity                         106 non-null    object
#  4   gender                            106 non-null    object
#  5   race                              106 non-null    object
#  6   vital_status                      106 non-null    object
#  7   year_of_birth                     106 non-null    int64
#  8   year_of_death                     106 non-null    int64
#  9   age_at_diagnosis                  106 non-null    int64
#  10  ann_arbor_b_symptoms              106 non-null    object
#  11  ann_arbor_clinical_stage          106 non-null    object
#  12  ann_arbor_extranodal_involvement  106 non-null    object
#  13  days_to_last_follow_up            106 non-null    int64
#  14  icd_10_code                       106 non-null    object
#  15  prior_treatment                   106 non-null    object
#  16  site_of_resection_or_biopsy       106 non-null    object
#  17  tissue_or_organ_of_origin         106 non-null    object
#  18  year_of_diagnosis                 106 non-null    int64
#  19  treatment_type                    106 non-null    object
# dtypes: int64(8), object(12)
# memory usage: 16.7+ KB

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    age_at_index  days_to_birth  days_to_death               ethnicity  gender  \
# 0            61         -22454            248  not hispanic or latino  female
# 1            61         -22454            248  not hispanic or latino  female
# 2            73         -27025             58  not hispanic or latino    male
# 3            73         -27025             58  not hispanic or latino    male
# 4            27         -10075            391      hispanic or latino  female
#
#     race vital_status  year_of_birth  year_of_death  age_at_diagnosis  \
# 0  asian         Dead           1952           2012             22454
# 1  asian         Dead           1952           2012             22454
# 2  asian         Dead           1940           2012             27025
# 3  asian         Dead           1940           2012             27025
# 4  white         Dead           1984           2012             10075
#
#   ann_arbor_b_symptoms ann_arbor_clinical_stage  \
# 0                   No                  Stage I
# 1                   No                  Stage I
# 2                   No                 Stage IV
# 3                   No                 Stage IV
# 4                   No                 Stage II
#
#   ann_arbor_extranodal_involvement  days_to_last_follow_up icd_10_code  \
# 0                               No                      22       C48.1
# 1                               No                      22       C48.1
# 2                               No                       6       C83.3
# 3                               No                       6       C83.3
# 4                               No                     982       C83.3
#
#   prior_treatment         site_of_resection_or_biopsy  \
# 0              No         Intra-abdominal lymph nodes
# 1              No         Intra-abdominal lymph nodes
# 2              No  Lymph nodes of head, face and neck
# 3              No  Lymph nodes of head, face and neck
# 4              No  Lymph nodes of head, face and neck
#
#             tissue_or_organ_of_origin  year_of_diagnosis  \
# 0         Intra-abdominal lymph nodes               2013
# 1         Intra-abdominal lymph nodes               2013
# 2  Lymph nodes of head, face and neck               2013
# 3  Lymph nodes of head, face and neck               2013
# 4  Lymph nodes of head, face and neck               2011
#
#                 treatment_type
# 0  Pharmaceutical Therapy, NOS
# 1       Radiation Therapy, NOS
# 2       Radiation Therapy, NOS
# 3  Pharmaceutical Therapy, NOS
# 4  Pharmaceutical Therapy, NOS

# %%
int_features=['age_at_index', 'days_to_birth', 'days_to_death', 'year_of_birth', 'year_of_death', 'age_at_diagnosis', 'days_to_last_follow_up', 'year_of_diagnosis']
for column in int_features:
  df[column]=df[column].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age_at_index                      106 non-null    int64
#  1   days_to_birth                     106 non-null    int64
#  2   days_to_death                     106 non-null    int64
#  3   ethnicity                         106 non-null    object
#  4   gender                            106 non-null    object
#  5   race                              106 non-null    object
#  6   vital_status                      106 non-null    object
#  7   year_of_birth                     106 non-null    int64
#  8   year_of_death                     106 non-null    int64
#  9   age_at_diagnosis                  106 non-null    int64
#  10  ann_arbor_b_symptoms              106 non-null    object
#  11  ann_arbor_clinical_stage          106 non-null    object
#  12  ann_arbor_extranodal_involvement  106 non-null    object
#  13  days_to_last_follow_up            106 non-null    int64
#  14  icd_10_code                       106 non-null    object
#  15  prior_treatment                   106 non-null    object
#  16  site_of_resection_or_biopsy       106 non-null    object
#  17  tissue_or_organ_of_origin         106 non-null    object
#  18  year_of_diagnosis                 106 non-null    int64
#  19  treatment_type                    106 non-null    object
# dtypes: int64(8), object(12)
# memory usage: 16.7+ KB

# %%
df_encoded=df.copy()
for col in df_encoded.select_dtypes(include=['object']).columns:
  df_encoded[col]=LabelEncoder().fit_transform(df_encoded[col])


df_encoded.head()
# Out:
#    age_at_index  days_to_birth  days_to_death  ethnicity  gender  race  \
# 0            61         -22454            248          1       0     0
# 1            61         -22454            248          1       0     0
# 2            73         -27025             58          1       1     0
# 3            73         -27025             58          1       1     0
# 4            27         -10075            391          0       0     2
#
#    vital_status  year_of_birth  year_of_death  age_at_diagnosis  \
# 0             1           1952           2012             22454
# 1             1           1952           2012             22454
# 2             1           1940           2012             27025
# 3             1           1940           2012             27025
# 4             1           1984           2012             10075
#
#    ann_arbor_b_symptoms  ann_arbor_clinical_stage  \
# 0                     0                         0
# 1                     0                         0
# 2                     0                         3
# 3                     0                         3
# 4                     0                         1
#
#    ann_arbor_extranodal_involvement  days_to_last_follow_up  icd_10_code  \
# 0                                 0                      22            2
# 1                                 0                      22            2
# 2                                 0                       6            9
# 3                                 0                       6            9
# 4                                 0                     982            9
#
#    prior_treatment  site_of_resection_or_biopsy  tissue_or_organ_of_origin  \
# 0                0                            8                          8
# 1                0                            8                          8
# 2                0                           12                         12
# 3                0                           12                         12
# 4                0                           12                         12
#
#    year_of_diagnosis  treatment_type
# 0               2013               0
# 1               2013               1
# 2               2013               1
# 3               2013               0
# 4               2011               0

# %%
correlation_with_target=df_encoded.corr()[['treatment_type']].drop('treatment_type').sort_values(by='treatment_type', ascending=False)
correlation_with_target
# Out:
#                                   treatment_type
# prior_treatment                         0.265221
# days_to_birth                           0.175225
# year_of_birth                           0.168073
# vital_status                            0.158163
# site_of_resection_or_biopsy             0.147378
# tissue_or_organ_of_origin               0.147378
# age_at_index                            0.145893
# ann_arbor_b_symptoms                    0.132140
# ann_arbor_clinical_stage                0.097935
# gender                                  0.092991
# ann_arbor_extranodal_involvement        0.089542
# race                                    0.070124
# year_of_diagnosis                       0.067914
# ethnicity                               0.051267
# icd_10_code                             0.040237
# year_of_death                           0.021062
# days_to_death                          -0.014576
# days_to_last_follow_up                 -0.019105
# age_at_diagnosis                       -0.175225

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_target.treatment_type, y=correlation_with_target.index, palette='viridis')
plt.xlabel('Coefficient of correlation')
plt.ylabel('Features')
plt.title('Correlation with Treatment Type')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. prior_treatment
# Признак указывает, было ли у пациента лечение до текущего диагноза.
#
# Источник:
#
# Медицинские карты (история болезни)
#
# Анкеты пациентов
#
# Электронные истории лечения (EHR/EMR)
#
# Категориальный признак: "yes", "no", "unknown" и т. д.
#
# 2. days_to_birth
# Количество дней от даты рождения до даты диагностики, в отрицательном значении (по стандарту TCGA, GDC, NCBI). Вычисляется.
#
# Это вспомогательный технический признак, часто встречается в геномных клинических датасетах.
#
# 3. year_of_birth
# Год рождения пациента (например, 1975)
#
# Источник:
#
# Из date_of_birth
#
# Из анкетных/регистрационных данных
#
# Может использоваться для определения когорты или анализа по возрастным группам.
#
#  4. age_at_diagnosis
# Возраст пациента на момент постановки диагноза (в годах). Вычисляется.
# Основной количественный признак для анализа риска.
#
# # Общий вывод:
# Признак	Источник	Комментарий
# prior_treatment	История болезни, анкета	Категориальный, вручную введённый
# days_to_birth	Вычислен из даты рождения и диагноза	Стандартизированное представление в GDC
# year_of_birth	Из даты рождения	Часто напрямую вводится
# age_at_diagnosis	Вычислен на основе days_to_birth	Ключевой числовой показатель возраста

# %% [markdown]
# ##ОКОНЧАТЕЛЬНЫЙ  ВЫВОД
#
# Больше всего на целевую переменную treatment_type влияют признаки: prior_treatment	0.265221
# days_to_birth	0.175225
# year_of_birth	0.168073
# age_at_diagnosis	-0.175225
#
# Т.е. Чем больше prior_treatment, days_to_birth, year_of_birth тем больше необхоимо проводить Radiation Therapy, NOS.
#
# Чем больше age_at_diagnosis по модулю тем больше необхоимо проводить Radiation Therapy, NOS.
